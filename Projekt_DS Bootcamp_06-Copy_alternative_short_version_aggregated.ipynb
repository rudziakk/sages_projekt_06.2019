# %%
# Importowanie potrzebnych pakietów:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

from sklearn.pipeline import make_pipeline, Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler, StandardScaler, OneHotEncoder, scale, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score, roc_curve, f1_score, roc_auc_score, classification_report
from xgboost.sklearn import XGBClassifier
from scipy.stats import norm
from scipy import stats
from sklearn.svm import SVC

from warnings import filterwarnings
filterwarnings("ignore")

# Ustawienia wyświetlania data frame'ów:
pd.set_option('display.max_columns', 50) # żeby nie ucinało kolumn przy wyświetlaniu
pd.set_option('float_format', '{:.2f}'.format) # floaty mają się zaogrąglać do dwóch miejść po przecinku

# %%
URL = 'https://raw.githubusercontent.com/saimadhu-polamuri/DataHakthon3X/master/dataSet/Train.csv'

def extract(url: str) -> pd.DataFrame:
    if url[:8] == 'https://' and url[-4:] == '.csv':
        return pd.read_csv(url, encoding='latin1', skipinitialspace=True)
    else:
        raise UnsupportedFormatError

def split_data(data: pd.DataFrame) -> pd.DataFrame:
    y = data.Disbursed
    X = data.drop(['Disbursed'], axis=1)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)
    return X_train, X_test, y_train, y_test

def print_df_description(df: pd.DataFrame) -> pd.DataFrame:
    df_size = df.shape[0]
    col_types = [df[column].dtype for column in df.columns]
    count_nan = [df[column].isna().sum(axis=0) for column in df.columns]
    nan_percentage = [n / df_size * 100 for n in count_nan]
    count_zeros = [(df.shape[0] - len(df[column].nonzero()[0])) for column in df.columns]
    zeros_percentage = [z / df_size * 100 for z in count_zeros]
    unique_values_num = [np.unique(df[column].astype(str)).size for column in df.columns]
    unique_values = [np.unique(df[column].astype(str)) for column in df.columns]
    df_describe = pd.DataFrame({
        'Column_names': df.columns, 'Column_types': col_types, 
        'Num_of_NaN': count_nan, 'NaN_%': nan_percentage, 
        'Num_of_zeros': count_zeros, 'Zeros_%': zeros_percentage, 
        'Unique_val_amt': unique_values_num, 'Unique_values': unique_values})
    return df_describe

# %%
data = extract(URL) # wczytanie danych z linku poprzez funkcję własną
X_train, X_test, y_train, y_test = split_data(data) # podział danych na zbiór treningowy i testowy

# %%
def get_unique_values(column: pd.DataFrame) -> dict:
    """
    Funkcja, która dla danej zmiennej w postaci pd.DataFrame tworzy słownik unikalnych wartości w taki sposób, 
    że kluczami będą kolejne liczby, zaś wartościami kolejne unikalne wartości zmiennej.
    Przykład.
    Dla zmiennej określającej płeć (Female / Male) wynik będzie następujący: {0: 'Female', 1: 'Male'}
    """
    unique_values = np.unique(column)
    wynik = {}
    for val in range(unique_values.size):
        wynik[val] = [unique_values[val]]
    return wynik

def get_groups(groups: dict) -> dict:
    """
    Funkcja, która stworzy schemat, dzięki któremu zmienna w pd.DataFrame będzie mogła zostać "zmapowana".
    Schemat tworzony jest na podstawie słownika, będącego wynikiem funkcji `get_unique_values`. 
    """
    wynik = {}
    for key, value in groups.items():
        for name in value:
            wynik[name] = int(key)
    return wynik

# %%
# schematy do mapowania zmiennych kategorycznych
gender_schema = get_groups(get_unique_values(X_train['Gender']))
mobile_verified_schema = get_groups(get_unique_values(X_train['Mobile_Verified']))
var1_schema = get_groups(get_unique_values(X_train['Var1']))
filled_form_schema = get_groups(get_unique_values(X_train['Filled_Form']))
device_type_schema = get_groups(get_unique_values(X_train['Device_Type']))
var2_schema = get_groups(get_unique_values(X_train['Var2']))

# tworzę ręcznie słownik dla zmapowania miesięcy, które w zmiennej są wpisane jako pierwsze 3 litery miesiąca
MONTH_GROUPS = {1: ['Jan'], 2: ['Feb'], 3: ['Mar'], 4: ['Apr'], 5: ['May'], 6: ['Jun'], 
                7: ['Jul'], 8: ['Aug'], 9: ['Sep'], 10: ['Oct'], 11: ['Nov'], 12: ['Dec'],}
months_schema = get_groups(MONTH_GROUPS)

# %%
def transform(df: pd.DataFrame) -> pd.DataFrame:
    YEAR = datetime.datetime.now().year

    df['Gender'].replace(gender_schema, inplace=True)
    df['Mobile_Verified'].replace(mobile_verified_schema, inplace=True)
    df['Var1'].replace(var1_schema, inplace=True)
    df['Filled_Form'].replace(filled_form_schema, inplace=True)
    df['Device_Type'].replace(device_type_schema, inplace=True)
    df['Var2'].replace(var2_schema, inplace=True)

    df.DOB = df.DOB.apply(lambda x: YEAR - int('19' + str(x[-2:])))

    df.Lead_Creation_Date = df.Lead_Creation_Date.apply(lambda x: (x[3:-3]))
    df['Lead_Creation_Date'].replace(months_schema, inplace=True)
    df.Lead_Creation_Date = df.Lead_Creation_Date.astype(int)

    df.Source = df.Source.apply(lambda x: x[1:]).astype(int)
    
    df.City = df.City.astype(str)
    df.City = df.City.apply(lambda x: x.upper()).astype(str)

    df.Employer_Name = df.Employer_Name.astype(str)
    df.Employer_Name = df.Employer_Name.apply(lambda x: x.upper())

    df.Salary_Account = df.Salary_Account.astype(str)
    df.Salary_Account = df.Salary_Account.apply(lambda x: x.upper())

    df.drop(['ID', 'LoggedIn'], axis=1, inplace=True)
    
    return df

# %%
# obrabiam wstępnie dane treningowe oraz wyświetlam opis danych
transform(X_train)
# print_df_description(X_train)
# Out:
#        Gender                 City  Monthly_Income  DOB  Lead_Creation_Date  \
# 83041       1              CHENNAI          210000   36                   7
# 34474       0                DELHI           10500   25                   6
# 48453       1               MUMBAI           48000   29                   6
# 27735       1                DELHI           23243   30                   6
# 82812       1               MUMBAI          129500   47                   7
# 41151       0               INDORE           38500   40                   6
# 23024       0               NAGPUR           14500   40                   5
# 83206       0            HYDERABAD           19000   27                   7
# 45644       0               MUMBAI           35000   37                   6
# 62154       0               MUMBAI           12000   28                   7
# 83491       1               MUMBAI           62000   41                   7
# 116         1               BASTAR           38000   48                   5
# 15011       1                SURAT           20000   34                   5
# 83538       1              CHENNAI           16000   29                   7
# 48873       0          BHUBANESWAR           34000   33                   6
# 67147       1                 PUNE          200000   37                   7
# 28347       1                 PUNE           23445   33                   6
# 56666       1                 PUNE           27000   30                   7
# 22932       1            HYDERABAD           54000   36                   5
# 63798       0            ALAPPUZHA           10000   47                   7
# 60834       1            ALLAHABAD           24000   32                   7
# 14731       1              KOLKATA           20000   27                   5
# 13034       0                DELHI           32500   32                   5
# 83579       1            HYDERABAD           55000   31                   7
# 50818       0             POLLACHI           10250   28                   6
# 19664       1             VADODARA           50000   36                   5
# 70925       1               JAIPUR           28000   33                   7
# 80175       1                DELHI           26000   31                   7
# 72876       1               MUMBAI           60000   34                   7
# 75192       0          GANDHINAGAR          190000   38                   7
# ...       ...                  ...             ...  ...                 ...
# 41196       1              CHENNAI           40000   35                   6
# 23045       1                DELHI           35000   34                   5
# 74439       1               MUMBAI           18000   30                   7
# 55792       0                 PUNE           27500   39                   7
# 11732       1                DELHI           58000   40                   5
# 40449       1            BENGALURU           55000   37                   6
# 78724       1            BENGALURU           12000   33                   7
# 19438       1              SONIPAT           16000   37                   5
# 81796       1           VIJAYAWADA           27000   34                   7
# 16889       1            HYDERABAD           20200   29                   5
# 54186       0  GAUTAM BUDDHA NAGAR           23000   36                   7
# 74581       0                HISAR           17500   30                   7
# 16704       1               MUMBAI           20400   32                   5
# 1083        0           RANGAREDDY           12000   50                   5
# 8711        1              CHENNAI           30000   33                   5
# 9068        0                DELHI           17500   31                   5
# 67229       0                DELHI            8000   28                   7
# 75384       1            HYDERABAD           43800   32                   7
# 62759       1          MURSHIDABAD           16825   39                   7
# 39610       0                 PUNE           38000   38                   6
# 57103       1             ARIYALUR           25000   38                   7
# 10483       1                DELHI          100000   39                   5
# 70226       0               JAIPUR           23800   35                   7
# 65661       0            BENGALURU           15800   30                   7
# 64641       0               MUMBAI           21500   34                   7
# 81089       1                DELHI           32000   31                   7
# 63141       1               HOWRAH          250000   35                   7
# 11944       0               MUMBAI           30000   30                   5
# 59484       1        VISAKHAPATNAM           32000   44                   7
# 31092       0                PATNA           10000   23                   6
#
#        Loan_Amount_Applied  Loan_Tenure_Applied  Existing_EMI  \
# 83041            200000.00                 0.00          0.00
# 34474            100000.00                 2.00       3500.00
# 48453                 0.00                 0.00          0.00
# 27735                 0.00                 0.00          0.00
# 82812           1000000.00                 5.00      38000.00
# 41151            300000.00                 5.00      18600.00
# 23024            100000.00                 3.00          0.00
# 83206                 0.00                 0.00          0.00
# 45644            300000.00                 1.00      20000.00
# 62154             70000.00                 1.00       5000.00
# 83491            600000.00                 5.00      20000.00
# 116              500000.00                 5.00      15000.00
# 15011                 0.00                 0.00          0.00
# 83538                 0.00                 0.00          0.00
# 48873            100000.00                 5.00       7100.00
# 67147            200000.00                 3.00      18000.00
# 28347            300000.00                 5.00          0.00
# 56666                 0.00                 0.00          0.00
# 22932            500000.00                 4.00       4000.00
# 63798             50000.00                 2.00       2500.00
# 60834                 0.00                 0.00          0.00
# 14731                 0.00                 0.00          0.00
# 13034            100000.00                 3.00       4300.00
# 83579           1000000.00                 5.00          0.00
# 50818            200000.00                 3.00          0.00
# 19664                 0.00                 0.00          0.00
# 70925                 0.00                 0.00          0.00
# 80175                 0.00                 0.00          0.00
# 72876                 0.00                 0.00      20000.00
# 75192                 0.00                 0.00          0.00
# ...                    ...                  ...           ...
# 41196            500000.00                 5.00          0.00
# 23045                 0.00                 0.00          0.00
# 74439                 0.00                 0.00          0.00
# 55792             40000.00                 3.00       1100.00
# 11732                 0.00                 0.00          0.00
# 40449           1000000.00                 5.00       9500.00
# 78724            200000.00                 3.00          0.00
# 19438            300000.00                 3.00          0.00
# 81796            200000.00                 5.00          0.00
# 16889            200000.00                 4.00          0.00
# 54186            100000.00                 0.00          0.00
# 74581            100000.00                 0.00       2000.00
# 16704            200000.00                 5.00          0.00
# 1083             100000.00                 2.00       2000.00
# 8711                  0.00                 0.00          0.00
# 9068                  0.00                 0.00          0.00
# 67229                 0.00                 0.00          0.00
# 75384            350000.00                 4.00       9049.00
# 62759            200000.00                 5.00          0.00
# 39610             30000.00                 1.00          0.00
# 57103                 0.00                 0.00          0.00
# 10483            200000.00                 2.00          0.00
# 70226            200000.00                 5.00       5000.00
# 65661            100000.00                 2.00          0.00
# 64641            300000.00                 5.00       6934.00
# 81089                 0.00                 0.00          0.00
# 63141           1000000.00                 5.00          0.00
# 11944                 0.00                 3.00      14000.00
# 59484            100000.00                 2.00          0.00
# 31092           1000000.00                 5.00       5000.00
#
#                                       Employer_Name           Salary_Account  \
# 83041                        ALKEM LABORATORIES LTD      STATE BANK OF INDIA
# 34474                        PAISLEY EXPORT PVT LTD                      NAN
# 48453           BNP PARIBAS INDIA SOLUTIONS PVT LTD                AXIS BANK
# 27735                 EXL SERVICE.COM INDIA PVT LTD               ICICI BANK
# 82812                     TYPE SLOWLY FOR AUTO FILL               ICICI BANK
# 41151                                 STI INDIA LTD                AXIS BANK
# 23024                            AARPEE ENTERPRISES                      NAN
# 83206                             TECH MAHINDRA LTD               ICICI BANK
# 45644                        INGRAM MICRO INDIA LTD                HDFC BANK
# 62154                               SUBHASH BHAGATE               ICICI BANK
# 83491                    BA CONTINUUM INDIA PVT LTD  STANDARD CHARTERED BANK
# 116                                        TEACHERS      STATE BANK OF INDIA
# 15011                       OMHARI TEXTILE PVT. LTD              CANARA BANK
# 83538             ARUDRA  ENGINEERS PRIVATE LIMITED           SYNDICATE BANK
# 48873                             BISWARANJAN BHOLA                AXIS BANK
# 67147                        GIRISH ATMARAM MAHAJAN               ICICI BANK
# 28347                                  DIPAK PATIL            SYNDICATE BANK
# 56666                                    VOLKSWAGEN                      NAN
# 22932                HIDDEN BRAINS INFOTECH PVT LTD                HDFC BANK
# 63798                                  PRIVATE FIRM               ICICI BANK
# 60834                ABBOTT TRUECARE PHARMA PVT LTD                HDFC BANK
# 14731                                  HT MEDIA LTD                HDFC BANK
# 13034                      EBSAVVY INFOTECH PVT LTD                HDFC BANK
# 83579           HINDUSTAN PETROLEUM CORPORATION LTD               ICICI BANK
# 50818                                   M.SASIKUMAR           SYNDICATE BANK
# 19664                           GOVERNMENT HOSPITAL           BANK OF BARODA
# 70925                                     BOSCH LTD               ICICI BANK
# 80175              BARCLAYS SHARED SERVICES PVT LTD                HDFC BANK
# 72876                      THERMO FISHER SCIENTIFIC                HDFC BANK
# 75192                          MER TELECOM TANZANIA                IDBI BANK
# ...                                             ...                      ...
# 41196                          HCL TECHNOLOGIES LTD                AXIS BANK
# 23045                          CROMPTON GREAVES LTD                AXIS BANK
# 74439                      ONWARD E-SERVICE PVT LTD               KOTAK BANK
# 55792                            MPTA EDUCATION LTD      STATE BANK OF INDIA
# 11732                                     BLOOMBURG                 YES BANK
# 40449                                         PHANI                HDFC BANK
# 78724                                     MANJUNATH                 UCO BANK
# 19438                       SONA PLASTIC INDUSTRIES                      NAN
# 81796                               BENNETT COLEMAN                HDFC BANK
# 16889                            BUILDMATE PROJECTS               ICICI BANK
# 54186                                          SOPL      STATE BANK OF INDIA
# 74581                            OM DIESELS PVT LTD                HDFC BANK
# 16704              TRIVONE DIGITAL SERVICES PVT LTD              CANARA BANK
# 1083                                    G.DURGA RAO               KOTAK BANK
# 8711                     ABBOTT HEALTH CARE PVT LTD                HDFC BANK
# 9068                        SAMARA AUTO MAX PVT LTD               KOTAK BANK
# 67229                       VASAN EYE CARE HOSPITAL                HDFC BANK
# 75384                    SEVENHILLS EHEALTH PVT.LTD     INDIAN OVERSEAS BANK
# 62759     AEGON RELIGARE LIFE INSURANCE COMPANY LTD                 CITIBANK
# 39610    SYMANTEC SOFTWARE & SERVICES INDIA PVT LTD                HDFC BANK
# 57103                                             0                      NAN
# 10483           NISSAN ASHOK LEYLAND POWERTRAIN LTD                HDFC BANK
# 70226                     VIVEKANAND PVT ITI JAIPUR                HDFC BANK
# 65661                        ALLEN CAREER INSTITUTE    CENTRAL BANK OF INDIA
# 64641        SHRI SAI KRISHNA TRANSPORT CORPORATION                      NAN
# 81089                         WEBHELP INDIA PVT LTD               ICICI BANK
# 63141  COGNIZANT TECHNOLOGY SOLUTIONS INDIA PVT LTD                 CITIBANK
# 11944                                  SNEHAL PATIL      STATE BANK OF INDIA
# 59484                                P.KISHORE BABU  STATE BANK OF HYDERABAD
# 31092                        NAVBHARATH FERTILISERS     PUNJAB NATIONAL BANK
#
#        Mobile_Verified  Var5  Var1  Loan_Amount_Submitted  \
# 83041                1    17    13              200000.00
# 34474                0     0    13                    nan
# 48453                1     8     2              730000.00
# 27735                1     3     1              360000.00
# 82812                1    13    13             1000000.00
# 41151                0     0    13                    nan
# 23024                0     0    13                    nan
# 83206                1     2    13              320000.00
# 45644                0     0    13                    nan
# 62154                0     0    13                    nan
# 83491                1    18    11              700000.00
# 116                  1    10    13              430000.00
# 15011                1     3    10              290000.00
# 83538                1     1    13              260000.00
# 48873                0     8    13                    nan
# 67147                1    12    13              200000.00
# 28347                1     3    10              300000.00
# 56666                1    11    11              440000.00
# 22932                1    15     9              500000.00
# 63798                0     0    13                    nan
# 60834                1     1    10              560000.00
# 14731                1     3    13              310000.00
# 13034                0    12    13                    nan
# 83579                1    17     8             1100000.00
# 50818                0     0    13                    nan
# 19664                1    14    13              820000.00
# 70925                1     5     2              500000.00
# 80175                1     6     9              450000.00
# 72876                1    17     8              330000.00
# 75192                0     0    13                    nan
# ...                ...   ...   ...                    ...
# 41196                1    14    13              500000.00
# 23045                1     7    13              700000.00
# 74439                1     1    13              290000.00
# 55792                0     0    13                    nan
# 11732                1     7     2             1000000.00
# 40449                1    15    13             1000000.00
# 78724                1     1    13              160000.00
# 19438                1     1    13              250000.00
# 81796                1     8    13              200000.00
# 16889                1     3    13              200000.00
# 54186                0     0    13                    nan
# 74581                0     1    13                    nan
# 16704                1     3     1              200000.00
# 1083                 0     0    13                    nan
# 8711                 1     6    10              490000.00
# 9068                 0     0    13                    nan
# 67229                0     0    13                    nan
# 75384                1    12     2              350000.00
# 62759                1     1    10              200000.00
# 39610                0     0    13                    nan
# 57103                1     0    13                    nan
# 10483                1    16    13              200000.00
# 70226                0     0    13                    nan
# 65661                0     1    13                    nan
# 64641                0     0    13                    nan
# 81089                1     2     8              570000.00
# 63141                1     8    13             1000000.00
# 11944                0     0    13                    nan
# 59484                1    10     3              100000.00
# 31092                0     0    13                    nan
#
#        Loan_Tenure_Submitted  Interest_Rate  Processing_Fee  \
# 83041                   4.00            nan             nan
# 34474                    nan            nan             nan
# 48453                   4.00          14.85        14600.00
# 27735                   5.00          16.75         7200.00
# 82812                   5.00            nan             nan
# 41151                    nan            nan             nan
# 23024                    nan            nan             nan
# 83206                   4.00            nan             nan
# 45644                    nan            nan             nan
# 62154                    nan            nan             nan
# 83491                   5.00          13.00         1000.00
# 116                     5.00            nan             nan
# 15011                   5.00          20.00         2900.00
# 83538                   4.00            nan             nan
# 48873                    nan            nan             nan
# 67147                   3.00            nan             nan
# 28347                   5.00          20.00         3000.00
# 56666                   4.00          14.49         4356.00
# 22932                   4.00          22.00        12500.00
# 63798                    nan            nan             nan
# 60834                   5.00          14.25         4480.00
# 14731                   5.00            nan             nan
# 13034                    nan            nan             nan
# 83579                   5.00          13.99         5500.00
# 50818                    nan            nan             nan
# 19664                   5.00            nan             nan
# 70925                   4.00          14.85        10000.00
# 80175                   4.00          27.00         9000.00
# 72876                   4.00          13.99         1650.00
# 75192                    nan            nan             nan
# ...                      ...            ...             ...
# 41196                   5.00            nan             nan
# 23045                   5.00            nan             nan
# 74439                   4.00            nan             nan
# 55792                    nan            nan             nan
# 11732                   5.00          14.85        20000.00
# 40449                   5.00            nan             nan
# 78724                   3.00            nan             nan
# 19438                   3.00            nan             nan
# 81796                   5.00            nan             nan
# 16889                   4.00            nan             nan
# 54186                    nan            nan             nan
# 74581                    nan            nan             nan
# 16704                   5.00          24.00         4000.00
# 1083                     nan            nan             nan
# 8711                    5.00          14.25         3920.00
# 9068                     nan            nan             nan
# 67229                    nan            nan             nan
# 75384                   4.00          14.85         7000.00
# 62759                   5.00          18.25         2000.00
# 39610                    nan            nan             nan
# 57103                    nan            nan             nan
# 10483                   2.00            nan             nan
# 70226                    nan            nan             nan
# 65661                    nan            nan             nan
# 64641                    nan            nan             nan
# 81089                   4.00          13.99         2850.00
# 63141                   5.00            nan             nan
# 11944                    nan            nan             nan
# 59484                   2.00          15.25         2000.00
# 31092                    nan            nan             nan
#
#        EMI_Loan_Submitted  Filled_Form  Device_Type  Var2  Source  Var4
# 83041                 nan            0            1     6     122     3
# 34474                 nan            0            1     1     133     1
# 48453            20260.98            1            0     2     122     5
# 27735             8898.61            1            0     2     133     5
# 82812                 nan            0            1     6     122     3
# 41151                 nan            0            1     1     133     1
# 23024                 nan            0            1     1     133     1
# 83206                 nan            0            0     6     122     3
# 45644                 nan            0            1     1     133     1
# 62154                 nan            0            1     6     122     1
# 83491            15927.15            1            1     6     122     5
# 116                   nan            0            1     1     133     3
# 15011             7683.23            1            0     2     151     5
# 83538                 nan            0            0     6     122     3
# 48873                 nan            0            1     1     159     3
# 67147                 nan            0            1     6     122     3
# 28347             7948.17            0            1     1     133     4
# 56666            12132.08            0            1     6     122     4
# 22932            15753.04            1            1     1     137     5
# 63798                 nan            0            1     6     122     1
# 60834            13102.92            1            0     6     122     5
# 14731                 nan            0            0     2     122     2
# 13034                 nan            0            1     1     133     3
# 83579            25589.37            0            1     6     122     4
# 50818                 nan            0            1     1     159     1
# 19664                 nan            0            0     2     133     3
# 70925            13877.39            1            0     6     122     5
# 80175            15427.05            1            0     6     122     5
# 72876             9016.08            1            1     6     122     5
# 75192                 nan            0            0     6     122     1
# ...                   ...          ...          ...   ...     ...   ...
# 41196                 nan            0            1     1     133     3
# 23045                 nan            0            0     2     133     2
# 74439                 nan            0            0     6     122     3
# 55792                 nan            0            1     6     122     1
# 11732            23711.27            1            0     2     122     5
# 40449                 nan            0            1     1     133     3
# 78724                 nan            0            1     6     122     3
# 19438                 nan            0            1     1     144     3
# 81796                 nan            0            1     6     122     3
# 16889                 nan            0            1     1     133     3
# 54186                 nan            0            1     6     122     1
# 74581                 nan            0            1     6     122     3
# 16704             5753.59            1            1     1     133     5
# 1083                  nan            0            1     1     133     1
# 8711             11465.05            1            0     5     133     5
# 9068                  nan            0            0     2     133     1
# 67229                 nan            0            0     6     122     1
# 75384             9714.17            0            1     6     122     4
# 62759             5105.92            1            1     6     122     5
# 39610                 nan            0            1     1     122     1
# 57103                 nan            0            1     6     122     0
# 10483                 nan            0            1     1     122     3
# 70226                 nan            0            1     6     122     1
# 65661                 nan            0            1     6     122     3
# 64641                 nan            0            1     6     122     1
# 81089            15573.23            1            0     6     122     5
# 63141                 nan            0            1     6     122     3
# 11944                 nan            0            1     1     133     1
# 59484             4860.55            0            1     6     122     4
# 31092                 nan            0            1     1     133     1
#
# [69616 rows x 23 columns]

# %%
# tworzę listy najczęściej występujących miast i banków
df_cities = pd.DataFrame(X_train.City.value_counts())
often_cities_list = (df_cities[(df_cities['City'] > 250)].index)

df_salary_accounts = pd.DataFrame(X_train.Salary_Account.value_counts())
often_banks_list = (df_salary_accounts[(df_salary_accounts['Salary_Account'] > 250)].index)

# %%
# obsługa outlier'ów - w pierwszej kolejności wypiszę rozkłądy ćwiartkowe i podstawowe statystyki
outliers = ['Monthly_Income', 'Loan_Amount_Applied', 'Existing_EMI', 'Loan_Amount_Submitted', 
            'Interest_Rate', 'Processing_Fee', 'EMI_Loan_Submitted']
Q1 = X_train.quantile(0.25)
Q2 = X_train.quantile(0.5)
Q3 = X_train.quantile(0.75)
IQR = Q3 - Q1

# %%
mins = np.min(X_train) # minimalne wartości zmiennych
maxs = np.max(X_train) # maksymalne -||-
means = np.mean(X_train) # średnie -||-
left = Q1 - 1.5 * IQR # wyliczam lewy brzeg zakresu, który należy uznać za normalny dla zmiennych
right = Q3 + 1.5 * IQR # analogicznie wyliczam prawy brzeg
std = np.std(X_train) # odchylenie standardowe

# %%
# wyświetlam powyższe wyliczenia dla zmiennych z outlier'ami
pd.DataFrame({'Q1': Q1[outliers], 'Q2': Q2[outliers], 'Q3': Q3[outliers], 'IQR': IQR[outliers], 
              'min': mins[outliers], 'max': maxs[outliers], 'std': std[outliers], 'mean': means[outliers],
              'left (Q1 - 1.5x IQR)': left[outliers], 'right (Q3 + 1.5x IQR)': right[outliers]})
# Out:
#                              Q1        Q2        Q3       IQR      min  \
# Monthly_Income         16500.00  25000.00  40000.00  23500.00        0
# Loan_Amount_Applied        0.00 100000.00 300000.00 300000.00     0.00
# Existing_EMI               0.00      0.00   3500.00   3500.00     0.00
# Loan_Amount_Submitted 200000.00 300000.00 500000.00 300000.00 50000.00
# Interest_Rate             15.25     18.00     20.00      4.75    11.99
# Processing_Fee          2000.00   4000.00   6250.00   4250.00   200.00
# EMI_Loan_Submitted      6492.52   9431.45  12970.28   6477.76  1176.41
#
#                               max        std      mean  left (Q1 - 1.5x IQR)  \
# Monthly_Income          444554443 2428931.76  62512.21             -18750.00
# Loan_Amount_Applied   10000000.00  355472.19 230043.25            -450000.00
# Existing_EMI          10000000.00   44280.53   3740.95              -5250.00
# Loan_Amount_Submitted  3000000.00  308807.21 395413.81            -250000.00
# Interest_Rate               37.00       5.84     19.20                  8.12
# Processing_Fee           50000.00    4752.86   5155.66              -4375.00
# EMI_Loan_Submitted      144748.28    7578.72  11028.62              -3224.12
#
#                        right (Q3 + 1.5x IQR)
# Monthly_Income                      75250.00
# Loan_Amount_Applied                750000.00
# Existing_EMI                         8750.00
# Loan_Amount_Submitted              950000.00
# Interest_Rate                          27.12
# Processing_Fee                      12625.00
# EMI_Loan_Submitted                  22686.92

# %%
# tworzę granice "normalności", które przyjmę dla zmiennych odstających
right_MonInc = right['Monthly_Income']
right_LoanAmtApp = right['Loan_Amount_Applied']
right_ExEMI = right['Existing_EMI']
right_LoanAmtSub = right['Loan_Amount_Submitted']
right_IntRate = right['Interest_Rate']
left_IntRate = left['Interest_Rate']
right_ProcFee = right['Processing_Fee']
right_EMISub = right['EMI_Loan_Submitted']

# %%
# grupy do zmapowania pozostałych zmiennych kategorycznych na numeryczne wg wcześniej ustalonej listy unikatów
city_schema = get_groups(get_unique_values(often_cities_list))
city_schema['OTHERS'] = 30
salary_schema = get_groups(get_unique_values(often_banks_list))
salary_schema['OTHERS'] = 30

# %% [markdown]
# #### **Tutaj dla braków danych zastosuję średnią zamiast zer oraz usunę zmienne, o których niewiele wiemy (np. Var1).**

# %%
def transform1(df: pd.DataFrame) -> pd.DataFrame:
    df.City = df.City.apply(lambda x: x if x in often_cities_list else 'OTHERS')
    df['City'].replace(city_schema, inplace=True)

    df.Salary_Account = df.Salary_Account.apply(lambda x: x if x in often_banks_list else 'OTHERS')
    df['Salary_Account'].replace(salary_schema, inplace=True)
    
    df.Interest_Rate.fillna(means.Interest_Rate, inplace=True) # zmienna jest obsługiwana poniżej, ale uzupełnienie 0 nie działało
    df.Loan_Tenure_Applied.fillna(means.Loan_Tenure_Applied, inplace=True)
    df.Loan_Tenure_Submitted.fillna(means.Loan_Tenure_Submitted, inplace=True)

    df.Monthly_Income = df.Monthly_Income.apply(
        lambda x: means.Monthly_Income if x == np.nan else x if x < right_MonInc else right_MonInc)
    df.Loan_Amount_Applied = df.Loan_Amount_Applied.apply(
        lambda x: means.Loan_Amount_Applied if x == np.nan else x if x < right_LoanAmtApp else right_LoanAmtApp)
    df.Existing_EMI = df.Existing_EMI.apply(
        lambda x: means.Existing_EMI if x == np.nan else x if x < right_ExEMI else right_ExEMI)
    df.Loan_Amount_Submitted = df.Loan_Amount_Submitted.apply(
        lambda x: means.Loan_Amount_Submitted if x == np.nan else x if x < right_LoanAmtSub else right_LoanAmtSub)
    df.Interest_Rate = df.Interest_Rate.apply(
        lambda x: right_IntRate if x > right_IntRate else left_IntRate if x < left_IntRate else x)
    df.Processing_Fee = df.Processing_Fee.apply(
        lambda x: means.Processing_Fee if x == np.nan else x if x < right_ProcFee else right_ProcFee)
    df.EMI_Loan_Submitted = df.EMI_Loan_Submitted.apply(
        lambda x: means.EMI_Loan_Submitted if x == np.nan else x if x < right_EMISub else right_EMISub)
    
    df.drop(['Employer_Name', 'Var5', 'Var1', 'Var2', 'Var4', 'Source'], axis=1, inplace=True)

    return df

# %%
# dokonuję finalnej transformacji danych
transform1(X_train)
# print_df_description(X_train)
# Out:
#        Gender  City  Monthly_Income  DOB  Lead_Creation_Date  \
# 83041       1     4        75250.00   36                   7
# 34474       0     7        10500.00   25                   6
# 48453       1    19        48000.00   29                   6
# 27735       1     7        23243.00   30                   6
# 82812       1    19        75250.00   47                   7
# 41151       0    13        38500.00   40                   6
# 23024       0    20        14500.00   40                   5
# 83206       0    12        19000.00   27                   7
# 45644       0    19        35000.00   37                   6
# 62154       0    19        12000.00   28                   7
# 83491       1    19        62000.00   41                   7
# 116         1    30        38000.00   48                   5
# 15011       1    25        20000.00   34                   5
# 83538       1     4        16000.00   29                   7
# 48873       0    30        34000.00   33                   6
# 67147       1    24        75250.00   37                   7
# 28347       1    24        23445.00   33                   6
# 56666       1    24        27000.00   30                   7
# 22932       1    12        54000.00   36                   5
# 63798       0    30        10000.00   47                   7
# 60834       1    30        24000.00   32                   7
# 14731       1    16        20000.00   27                   5
# 13034       0     7        32500.00   32                   5
# 83579       1    12        55000.00   31                   7
# 50818       0    30        10250.00   28                   6
# 19664       1    27        50000.00   36                   5
# 70925       1    14        28000.00   33                   7
# 80175       1     7        26000.00   31                   7
# 72876       1    19        60000.00   34                   7
# 75192       0    30        75250.00   38                   7
# ...       ...   ...             ...  ...                 ...
# 41196       1     4        40000.00   35                   6
# 23045       1     7        35000.00   34                   5
# 74439       1    19        18000.00   30                   7
# 55792       0    24        27500.00   39                   7
# 11732       1     7        58000.00   40                   5
# 40449       1     1        55000.00   37                   6
# 78724       1     1        12000.00   33                   7
# 19438       1    30        16000.00   37                   5
# 81796       1    30        27000.00   34                   7
# 16889       1    12        20200.00   29                   5
# 54186       0     9        23000.00   36                   7
# 74581       0    30        17500.00   30                   7
# 16704       1    19        20400.00   32                   5
# 1083        0    30        12000.00   50                   5
# 8711        1     4        30000.00   33                   5
# 9068        0     7        17500.00   31                   5
# 67229       0     7         8000.00   28                   7
# 75384       1    12        43800.00   32                   7
# 62759       1    30        16825.00   39                   7
# 39610       0    24        38000.00   38                   6
# 57103       1    30        25000.00   38                   7
# 10483       1     7        75250.00   39                   5
# 70226       0    14        23800.00   35                   7
# 65661       0     1        15800.00   30                   7
# 64641       0    19        21500.00   34                   7
# 81089       1     7        32000.00   31                   7
# 63141       1    30        75250.00   35                   7
# 11944       0    19        30000.00   30                   5
# 59484       1    28        32000.00   44                   7
# 31092       0    23        10000.00   23                   6
#
#        Loan_Amount_Applied  Loan_Tenure_Applied  Existing_EMI  Salary_Account  \
# 83041            200000.00                 0.00          0.00              25
# 34474            100000.00                 2.00       3500.00              19
# 48453                 0.00                 0.00          0.00               1
# 27735                 0.00                 0.00          0.00              11
# 82812            750000.00                 5.00       8750.00              11
# 41151            300000.00                 5.00       8750.00               1
# 23024            100000.00                 3.00          0.00              19
# 83206                 0.00                 0.00          0.00              11
# 45644            300000.00                 1.00       8750.00               9
# 62154             70000.00                 1.00       5000.00              11
# 83491            600000.00                 5.00       8750.00              22
# 116              500000.00                 5.00       8750.00              25
# 15011                 0.00                 0.00          0.00               5
# 83538                 0.00                 0.00          0.00              26
# 48873            100000.00                 5.00       7100.00               1
# 67147            200000.00                 3.00       8750.00              11
# 28347            300000.00                 5.00          0.00              26
# 56666                 0.00                 0.00          0.00              19
# 22932            500000.00                 4.00       4000.00               9
# 63798             50000.00                 2.00       2500.00              11
# 60834                 0.00                 0.00          0.00               9
# 14731                 0.00                 0.00          0.00               9
# 13034            100000.00                 3.00       4300.00               9
# 83579            750000.00                 5.00          0.00              11
# 50818            200000.00                 3.00          0.00              26
# 19664                 0.00                 0.00          0.00               2
# 70925                 0.00                 0.00          0.00              11
# 80175                 0.00                 0.00          0.00               9
# 72876                 0.00                 0.00       8750.00               9
# 75192                 0.00                 0.00          0.00              12
# ...                    ...                  ...           ...             ...
# 41196            500000.00                 5.00          0.00               1
# 23045                 0.00                 0.00          0.00               1
# 74439                 0.00                 0.00          0.00              18
# 55792             40000.00                 3.00       1100.00              25
# 11732                 0.00                 0.00          0.00              28
# 40449            750000.00                 5.00       8750.00               9
# 78724            200000.00                 3.00          0.00              30
# 19438            300000.00                 3.00          0.00              19
# 81796            200000.00                 5.00          0.00               9
# 16889            200000.00                 4.00          0.00              11
# 54186            100000.00                 0.00          0.00              25
# 74581            100000.00                 0.00       2000.00               9
# 16704            200000.00                 5.00          0.00               5
# 1083             100000.00                 2.00       2000.00              18
# 8711                  0.00                 0.00          0.00               9
# 9068                  0.00                 0.00          0.00              18
# 67229                 0.00                 0.00          0.00               9
# 75384            350000.00                 4.00       8750.00              14
# 62759            200000.00                 5.00          0.00               7
# 39610             30000.00                 1.00          0.00               9
# 57103                 0.00                 0.00          0.00              19
# 10483            200000.00                 2.00          0.00               9
# 70226            200000.00                 5.00       5000.00               9
# 65661            100000.00                 2.00          0.00               6
# 64641            300000.00                 5.00       6934.00              19
# 81089                 0.00                 0.00          0.00              11
# 63141            750000.00                 5.00          0.00               7
# 11944                 0.00                 3.00       8750.00              25
# 59484            100000.00                 2.00          0.00              24
# 31092            750000.00                 5.00       5000.00              21
#
#        Mobile_Verified  Loan_Amount_Submitted  Loan_Tenure_Submitted  \
# 83041                1              200000.00                   4.00
# 34474                0              950000.00                   3.89
# 48453                1              730000.00                   4.00
# 27735                1              360000.00                   5.00
# 82812                1              950000.00                   5.00
# 41151                0              950000.00                   3.89
# 23024                0              950000.00                   3.89
# 83206                1              320000.00                   4.00
# 45644                0              950000.00                   3.89
# 62154                0              950000.00                   3.89
# 83491                1              700000.00                   5.00
# 116                  1              430000.00                   5.00
# 15011                1              290000.00                   5.00
# 83538                1              260000.00                   4.00
# 48873                0              950000.00                   3.89
# 67147                1              200000.00                   3.00
# 28347                1              300000.00                   5.00
# 56666                1              440000.00                   4.00
# 22932                1              500000.00                   4.00
# 63798                0              950000.00                   3.89
# 60834                1              560000.00                   5.00
# 14731                1              310000.00                   5.00
# 13034                0              950000.00                   3.89
# 83579                1              950000.00                   5.00
# 50818                0              950000.00                   3.89
# 19664                1              820000.00                   5.00
# 70925                1              500000.00                   4.00
# 80175                1              450000.00                   4.00
# 72876                1              330000.00                   4.00
# 75192                0              950000.00                   3.89
# ...                ...                    ...                    ...
# 41196                1              500000.00                   5.00
# 23045                1              700000.00                   5.00
# 74439                1              290000.00                   4.00
# 55792                0              950000.00                   3.89
# 11732                1              950000.00                   5.00
# 40449                1              950000.00                   5.00
# 78724                1              160000.00                   3.00
# 19438                1              250000.00                   3.00
# 81796                1              200000.00                   5.00
# 16889                1              200000.00                   4.00
# 54186                0              950000.00                   3.89
# 74581                0              950000.00                   3.89
# 16704                1              200000.00                   5.00
# 1083                 0              950000.00                   3.89
# 8711                 1              490000.00                   5.00
# 9068                 0              950000.00                   3.89
# 67229                0              950000.00                   3.89
# 75384                1              350000.00                   4.00
# 62759                1              200000.00                   5.00
# 39610                0              950000.00                   3.89
# 57103                1              950000.00                   3.89
# 10483                1              200000.00                   2.00
# 70226                0              950000.00                   3.89
# 65661                0              950000.00                   3.89
# 64641                0              950000.00                   3.89
# 81089                1              570000.00                   4.00
# 63141                1              950000.00                   5.00
# 11944                0              950000.00                   3.89
# 59484                1              100000.00                   2.00
# 31092                0              950000.00                   3.89
#
#        Interest_Rate  Processing_Fee  EMI_Loan_Submitted  Filled_Form  \
# 83041          19.20        12625.00            22686.92            0
# 34474          19.20        12625.00            22686.92            0
# 48453          14.85        12625.00            20260.98            1
# 27735          16.75         7200.00             8898.61            1
# 82812          19.20        12625.00            22686.92            0
# 41151          19.20        12625.00            22686.92            0
# 23024          19.20        12625.00            22686.92            0
# 83206          19.20        12625.00            22686.92            0
# 45644          19.20        12625.00            22686.92            0
# 62154          19.20        12625.00            22686.92            0
# 83491          13.00         1000.00            15927.15            1
# 116            19.20        12625.00            22686.92            0
# 15011          20.00         2900.00             7683.23            1
# 83538          19.20        12625.00            22686.92            0
# 48873          19.20        12625.00            22686.92            0
# 67147          19.20        12625.00            22686.92            0
# 28347          20.00         3000.00             7948.17            0
# 56666          14.49         4356.00            12132.08            0
# 22932          22.00        12500.00            15753.04            1
# 63798          19.20        12625.00            22686.92            0
# 60834          14.25         4480.00            13102.92            1
# 14731          19.20        12625.00            22686.92            0
# 13034          19.20        12625.00            22686.92            0
# 83579          13.99         5500.00            22686.92            0
# 50818          19.20        12625.00            22686.92            0
# 19664          19.20        12625.00            22686.92            0
# 70925          14.85        10000.00            13877.39            1
# 80175          27.00         9000.00            15427.05            1
# 72876          13.99         1650.00             9016.08            1
# 75192          19.20        12625.00            22686.92            0
# ...              ...             ...                 ...          ...
# 41196          19.20        12625.00            22686.92            0
# 23045          19.20        12625.00            22686.92            0
# 74439          19.20        12625.00            22686.92            0
# 55792          19.20        12625.00            22686.92            0
# 11732          14.85        12625.00            22686.92            1
# 40449          19.20        12625.00            22686.92            0
# 78724          19.20        12625.00            22686.92            0
# 19438          19.20        12625.00            22686.92            0
# 81796          19.20        12625.00            22686.92            0
# 16889          19.20        12625.00            22686.92            0
# 54186          19.20        12625.00            22686.92            0
# 74581          19.20        12625.00            22686.92            0
# 16704          24.00         4000.00             5753.59            1
# 1083           19.20        12625.00            22686.92            0
# 8711           14.25         3920.00            11465.05            1
# 9068           19.20        12625.00            22686.92            0
# 67229          19.20        12625.00            22686.92            0
# 75384          14.85         7000.00             9714.17            0
# 62759          18.25         2000.00             5105.92            1
# 39610          19.20        12625.00            22686.92            0
# 57103          19.20        12625.00            22686.92            0
# 10483          19.20        12625.00            22686.92            0
# 70226          19.20        12625.00            22686.92            0
# 65661          19.20        12625.00            22686.92            0
# 64641          19.20        12625.00            22686.92            0
# 81089          13.99         2850.00            15573.23            1
# 63141          19.20        12625.00            22686.92            0
# 11944          19.20        12625.00            22686.92            0
# 59484          15.25         2000.00             4860.55            0
# 31092          19.20        12625.00            22686.92            0
#
#        Device_Type
# 83041            1
# 34474            1
# 48453            0
# 27735            0
# 82812            1
# 41151            1
# 23024            1
# 83206            0
# 45644            1
# 62154            1
# 83491            1
# 116              1
# 15011            0
# 83538            0
# 48873            1
# 67147            1
# 28347            1
# 56666            1
# 22932            1
# 63798            1
# 60834            0
# 14731            0
# 13034            1
# 83579            1
# 50818            1
# 19664            0
# 70925            0
# 80175            0
# 72876            1
# 75192            0
# ...            ...
# 41196            1
# 23045            0
# 74439            0
# 55792            1
# 11732            0
# 40449            1
# 78724            1
# 19438            1
# 81796            1
# 16889            1
# 54186            1
# 74581            1
# 16704            1
# 1083             1
# 8711             0
# 9068             0
# 67229            0
# 75384            1
# 62759            1
# 39610            1
# 57103            1
# 10483            1
# 70226            1
# 65661            1
# 64641            1
# 81089            0
# 63141            1
# 11944            1
# 59484            1
# 31092            1
#
# [69616 rows x 17 columns]

# %%
# analogicznie transformuję dane testowe
transform(X_test)
transform1(X_test)
# print_df_description(X_test)
# Out:
#        Gender  City  Monthly_Income  DOB  Lead_Creation_Date  \
# 66075       1     1        23000.00   27                   7
# 23787       0     1        75250.00   36                   5
# 82963       0    12        18000.00   30                   7
# 65127       1     8        75250.00   35                   7
# 25243       0    11        30000.00   24                   5
# 20845       0    19        19800.00   32                   5
# 61037       0    16        10000.00   34                   7
# 84264       1    30        37000.00   30                   7
# 19047       0     7        17000.00   44                   5
# 2651        0     1        28000.00   29                   5
# 2020        0    24        51000.00   28                   5
# 37088       0     4        37000.00   33                   6
# 27428       1    12        25000.00   32                   6
# 58892       0     4        25000.00   36                   7
# 68055       1     1        54000.00   34                   7
# 26435       1    24        17000.00   34                   5
# 63458       0    27        30000.00   29                   7
# 30970       0     7        35000.00   46                   6
# 46530       1     3        13000.00   33                   6
# 31898       1    30        30000.00   26                   6
# 22962       1    12        31000.00   31                   5
# 62332       1     7        34000.00   30                   7
# 9486        0    11        15600.00   30                   5
# 135         0    30        50000.00   58                   5
# 36459       0     4        14800.00   29                   6
# 12336       1    30        24000.00   26                   5
# 65831       0    19        45000.00   32                   7
# 54198       1     7        29500.00   56                   7
# 19746       1    30        75250.00   29                   5
# 23500       1     1        75250.00   41                   5
# ...       ...   ...             ...  ...                 ...
# 85978       0     7        11500.00   36                   7
# 83013       0    30        16450.00   61                   7
# 53856       1     1        40000.00   29                   6
# 58846       0    12        20115.00   40                   7
# 65079       0     4        20000.00   36                   7
# 69950       1    14        18000.00   29                   7
# 63102       1    24        12600.00   34                   7
# 73688       0     4        46000.00   34                   7
# 23487       0    19        15000.00   31                   5
# 21414       0     1        15000.00   31                   5
# 61418       1     7        25000.00   40                   7
# 5610        1    19        32000.00   32                   5
# 83389       1     4        29000.00   34                   7
# 40457       1     7        75250.00   34                   6
# 16258       1    11        50000.00   35                   5
# 9666        0     7         8500.00   32                   5
# 54364       1    28        52969.00   50                   7
# 13298       1    10        50000.00   49                   5
# 85617       1    19        75250.00   32                   7
# 24060       0    17         9000.00   37                   5
# 5005        0     4        18500.00   32                   5
# 85065       1     1        30000.00   29                   7
# 66826       0    21        20000.00   29                   7
# 34043       0    12        23900.00   28                   6
# 6695        1    22        26000.00   37                   5
# 27942       1     4        22000.00   28                   6
# 78540       1    24        29000.00   36                   7
# 3836        0    24        50000.00   34                   5
# 23133       0    11        11142.00   32                   5
# 62966       0     4        24000.00   27                   7
#
#        Loan_Amount_Applied  Loan_Tenure_Applied  Existing_EMI  Salary_Account  \
# 66075            200000.00                 3.00       4000.00              11
# 23787            750000.00                 5.00       8750.00               7
# 82963            300000.00                 5.00          0.00               2
# 65127            200000.00                 3.00          0.00              18
# 25243                 0.00                 0.00          0.00              19
# 20845             50000.00                 2.00          0.00              19
# 61037                 0.00                 0.00          0.00              19
# 84264            200000.00                 5.00          0.00               0
# 19047            150000.00                 3.00       5000.00              20
# 2651             300000.00                 2.00          0.00               8
# 2020             500000.00                 3.00       8750.00               9
# 37088                 0.00                 1.00       1814.00              17
# 27428            100000.00                 2.00       3550.00              11
# 58892            200000.00                 3.00          0.00              11
# 68055            750000.00                 3.00          0.00              11
# 26435            750000.00                 5.00          0.00              11
# 63458            100000.00                 1.00          0.00              25
# 30970                 0.00                 0.00          0.00              25
# 46530                 0.00                 0.00          0.00              30
# 31898                 0.00                 0.00          0.00              25
# 22962            300000.00                 4.00          0.00               9
# 62332            500000.00                 5.00          0.00               1
# 9486             100000.00                 3.00          0.00              11
# 135              200000.00                 2.00       8750.00              25
# 36459            100000.00                 2.00          0.00              11
# 12336            200000.00                 3.00          0.00              20
# 65831                 0.00                 0.00          0.00              25
# 54198            200000.00                 4.00       4500.00              22
# 19746            100000.00                 3.00          0.00              11
# 23500                 0.00                 0.00          0.00               8
# ...                    ...                  ...           ...             ...
# 85978            300000.00                 4.00       5000.00               1
# 83013            500000.00                 0.00          0.00              25
# 53856            100000.00                 2.00       8750.00               9
# 58846            300000.00                 5.00          0.00               9
# 65079            300000.00                 2.00          0.00               1
# 69950                 0.00                 0.00          0.00              21
# 63102                 0.00                 0.00          0.00               1
# 73688            150000.00                 2.00          0.00              30
# 23487            200000.00                 4.00       5000.00               9
# 21414            200000.00                 3.00          0.00              25
# 61418                 0.00                 0.00          0.00              19
# 5610             100000.00                 3.00       5000.00               9
# 83389                 0.00                 0.00          0.00              25
# 40457            750000.00                 5.00          0.00               9
# 16258                 0.00                 0.00          0.00              19
# 9666             200000.00                 2.00          0.00              30
# 54364                 0.00                 0.00          0.00              25
# 13298                 0.00                 0.00          0.00              11
# 85617                 0.00                 0.00          0.00               9
# 24060            100000.00                 3.00       2000.00              27
# 5005             750000.00                 5.00       8500.00              25
# 85065                 0.00                 0.00          0.00              11
# 66826            300000.00                 0.00       8750.00               9
# 34043            500000.00                 3.00          0.00              22
# 6695             140000.00                 3.00       7825.00              11
# 27942                 0.00                 0.00          0.00               7
# 78540            200000.00                 5.00       8750.00               1
# 3836             300000.00                 1.00          0.00              25
# 23133            200000.00                 5.00       2000.00              27
# 62966                 0.00                 0.00          0.00               7
#
#        Mobile_Verified  Loan_Amount_Submitted  Loan_Tenure_Submitted  \
# 66075                1              200000.00                   3.00
# 23787                0              950000.00                   3.89
# 82963                0              950000.00                   3.89
# 65127                1              200000.00                   3.00
# 25243                0              950000.00                   3.89
# 20845                0              950000.00                   3.89
# 61037                0              950000.00                   3.89
# 84264                1              200000.00                   5.00
# 19047                0              950000.00                   3.89
# 2651                 0              950000.00                   3.89
# 2020                 0              950000.00                   3.89
# 37088                1              170000.00                   3.00
# 27428                1              100000.00                   2.00
# 58892                0              950000.00                   3.89
# 68055                1              950000.00                   3.00
# 26435                1              380000.00                   5.00
# 63458                1              100000.00                   1.00
# 30970                1              540000.00                   5.00
# 46530                1              190000.00                   4.00
# 31898                1              450000.00                   5.00
# 22962                1              300000.00                   4.00
# 62332                1              500000.00                   5.00
# 9486                 0              950000.00                   3.89
# 135                  1              200000.00                   2.00
# 36459                0              950000.00                   3.89
# 12336                1              200000.00                   3.00
# 65831                1              780000.00                   4.00
# 54198                1              200000.00                   4.00
# 19746                1              100000.00                   3.00
# 23500                1              950000.00                   5.00
# ...                ...                    ...                    ...
# 85978                0              950000.00                   3.89
# 83013                0              950000.00                   3.89
# 53856                1              100000.00                   2.00
# 58846                0              950000.00                   3.89
# 65079                0              950000.00                   3.89
# 69950                1              290000.00                   4.00
# 63102                1              200000.00                   4.00
# 73688                0              950000.00                   3.89
# 23487                1              130000.00                   4.00
# 21414                0              950000.00                   3.89
# 61418                1              950000.00                   3.89
# 5610                 1              100000.00                   3.00
# 83389                1              540000.00                   4.00
# 40457                1              950000.00                   5.00
# 16258                1              950000.00                   3.89
# 9666                 0              950000.00                   3.89
# 54364                1              900000.00                   4.00
# 13298                1              820000.00                   5.00
# 85617                1              950000.00                   4.00
# 24060                0              950000.00                   3.89
# 5005                 0              950000.00                   3.89
# 85065                1              560000.00                   4.00
# 66826                0              950000.00                   3.89
# 34043                0              950000.00                   3.89
# 6695                 1              140000.00                   3.00
# 27942                1              340000.00                   5.00
# 78540                1              180000.00                   4.00
# 3836                 1              300000.00                   1.00
# 23133                0              950000.00                   3.89
# 62966                0              950000.00                   3.89
#
#        Interest_Rate  Processing_Fee  EMI_Loan_Submitted  Filled_Form  \
# 66075          19.20        12625.00            22686.92            0
# 23787          19.20        12625.00            22686.92            0
# 82963          19.20        12625.00            22686.92            0
# 65127          19.20        12625.00            22686.92            0
# 25243          19.20        12625.00            22686.92            0
# 20845          19.20        12625.00            22686.92            0
# 61037          19.20        12625.00            22686.92            0
# 84264          19.20        12625.00            22686.92            0
# 19047          19.20        12625.00            22686.92            0
# 2651           19.20        12625.00            22686.92            0
# 2020           19.20        12625.00            22686.92            0
# 37088          19.75         2550.00             6296.18            0
# 27428          19.20        12625.00            22686.92            0
# 58892          19.20        12625.00            22686.92            0
# 68055          19.20        12625.00            22686.92            0
# 26435          19.20        12625.00            22686.92            0
# 63458          19.20        12625.00            22686.92            0
# 30970          19.20        12625.00            22686.92            0
# 46530          27.12         3800.00             7462.06            1
# 31898          20.00         4500.00            11922.25            1
# 22962          15.35         1500.00             8402.55            0
# 62332          19.20        12625.00            22686.92            0
# 9486           19.20        12625.00            22686.92            0
# 135            19.20        12625.00            22686.92            0
# 36459          19.20        12625.00            22686.92            0
# 12336          24.00         4000.00             7846.57            1
# 65831          15.25        12625.00            21806.96            1
# 54198          16.50         3000.00             5719.40            0
# 19746          21.50         2500.00             3793.23            1
# 23500          20.00        12625.00            22686.92            1
# ...              ...             ...                 ...          ...
# 85978          19.20        12625.00            22686.92            0
# 83013          19.20        12625.00            22686.92            0
# 53856          19.20        12625.00            22686.92            0
# 58846          19.20        12625.00            22686.92            0
# 65079          19.20        12625.00            22686.92            0
# 69950          19.20        12625.00            22686.92            0
# 63102          19.20        12625.00            22686.92            0
# 73688          19.20        12625.00            22686.92            0
# 23487          19.20        12625.00            22686.92            0
# 21414          19.20        12625.00            22686.92            0
# 61418          19.20        12625.00            22686.92            0
# 5610           15.75         1500.00             3503.37            0
# 83389          19.20        12625.00            22686.92            0
# 40457          19.20        12625.00            22686.92            0
# 16258          19.20        12625.00            22686.92            0
# 9666           19.20        12625.00            22686.92            0
# 54364          19.20        12625.00            22686.92            0
# 13298          14.85        12625.00            19443.24            1
# 85617          13.99         7500.00            22686.92            1
# 24060          19.20        12625.00            22686.92            0
# 5005           19.20        12625.00            22686.92            0
# 85065          19.20        12625.00            22686.92            0
# 66826          19.20        12625.00            22686.92            0
# 34043          19.20        12625.00            22686.92            0
# 6695           19.20        12625.00            22686.92            0
# 27942          16.75         6800.00             8404.24            1
# 78540          27.00         3600.00             6170.82            1
# 3836           19.20        12625.00            22686.92            0
# 23133          19.20        12625.00            22686.92            0
# 62966          19.20        12625.00            22686.92            0
#
#        Device_Type
# 66075            1
# 23787            1
# 82963            1
# 65127            1
# 25243            0
# 20845            1
# 61037            1
# 84264            1
# 19047            1
# 2651             1
# 2020             1
# 37088            1
# 27428            1
# 58892            1
# 68055            1
# 26435            1
# 63458            1
# 30970            0
# 46530            0
# 31898            0
# 22962            1
# 62332            1
# 9486             1
# 135              1
# 36459            1
# 12336            1
# 65831            0
# 54198            1
# 19746            1
# 23500            0
# ...            ...
# 85978            1
# 83013            1
# 53856            1
# 58846            1
# 65079            1
# 69950            0
# 63102            0
# 73688            1
# 23487            1
# 21414            1
# 61418            1
# 5610             1
# 83389            0
# 40457            1
# 16258            1
# 9666             1
# 54364            0
# 13298            0
# 85617            0
# 24060            1
# 5005             1
# 85065            0
# 66826            1
# 34043            1
# 6695             1
# 27942            0
# 78540            1
# 3836             1
# 23133            1
# 62966            1
#
# [17404 rows x 17 columns]

# %%
# tworzę klasę do selekcji zmiennych wg nazw
class ColumnSelectorByName(TransformerMixin, BaseEstimator):
    
    def __init__(self, columns):
        self.columns = columns
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        return X[self.columns]

# wypisuję listy zmiennych, które oryginalnie były kategoryczne i użyję na nich 
# OneHotEncoder'a, a także zmienne numeryczne, które zestandaryzuję
originally_categorical_features = ['Gender', 'City', 'DOB', 'Lead_Creation_Date', 
                                   'Salary_Account', 'Mobile_Verified', 'Filled_Form', 'Device_Type']
numerical_features = ['Monthly_Income', 'Loan_Amount_Applied', 'Loan_Tenure_Applied', 
                      'Existing_EMI', 'Interest_Rate', 'Loan_Amount_Submitted', 'Loan_Tenure_Submitted', 
                      'Processing_Fee', 'EMI_Loan_Submitted']
    
# tworzę pipeline'y, które użyję do transformatora
categorical_pipeline = Pipeline([
    ('selector', ColumnSelectorByName(originally_categorical_features)),
    ('onehot', OneHotEncoder(sparse=False, handle_unknown='ignore')),
])

numeric_pipeline = Pipeline([
    ('selector', ColumnSelectorByName(numerical_features)),
    ('scaler', StandardScaler()),
])

# transformator - preprocessor, który agreguje powyższe pipeline'y
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_pipeline, numerical_features),
        ('cat', categorical_pipeline, originally_categorical_features),
    ]
)

# %%
# tworzę np.array mapujący wagi dla y_train - niektóre modele (np. XGBoost) nie przujmuje wag jako słowników
df_weights = y_train.copy()
weight_0 = 0.5
weight_1 = 10
df_weights = df_weights.apply(lambda x: weight_0 if x == 0 else weight_1)
class_weights0510 = df_weights.values

# %%
# analogicznię robię listę dla innych wag, 0.5 / 5:
df_weights = y_train.copy()
weight_0 = 0.5
weight_1 = 5
df_weights = df_weights.apply(lambda x: weight_0 if x == 0 else weight_1)
class_weights055 = df_weights.values

# %% [markdown]
# # Zagregowany GridSearch

# %%
names_agg = ['LogisticRegression', 'XGBoost', 'RandomForestClassifier',]

models_agg = [[('scaler', preprocessor), ('model', LogisticRegression())], 
              [('model', XGBClassifier())], 
              [('model', RandomForestClassifier())]]

param_grids = [
    {'model__C': [0.1, 0.01, 0.001], 
     'model__class_weight': [{0: 0.5, 1: 5}, {0: 0.5, 1:10}],
     'model__penalty': ['l1', 'l2'],
     'model__tol': [0.1, 0.01, 0.001],
    },
    {'model__learning_rate': [0.1, 0.01], 
     'model__max_depth': [50, 75, 100],
     'model__n_estimators': [50, 75],
    },
    {'model__class_weight': [{0: 0.5, 1: 5}, {0: 0.5, 1: 10}],
     'model__max_depth': [20, 50, 75, 100],
     'model__min_samples_leaf': [400, 500, 750],
     'model__n_estimators': [20, 50, 75, 100],
    },
]           

best_models_agg = []
best_params_agg = []

for name, pipe, params in zip(names_agg, models_agg, param_grids):
    print("---!!!---", name)
    pipeline = Pipeline(pipe)
    if name == 'XGBoost':
        gs = GridSearchCV(estimator=pipeline, param_grid=params, refit=True, return_train_score=True, 
                          fit_params={'model__sample_weight': class_weights0510}, scoring='f1')
    else:
        gs = GridSearchCV(estimator=pipeline, param_grid=params, refit=True, return_train_score=True, 
                          scoring='f1')
    gs.fit(X_train, y_train)
    
    for mean, std, parametry, fittime in zip(
                            gs.cv_results_["mean_test_score"],
                            gs.cv_results_["std_test_score"],
                            gs.cv_results_["params"],
                            gs.cv_results_["mean_fit_time"]):
        print(f'mean = {(np.round(mean, 5))} || std = {(np.round(std, 5))} || time [s] = {np.round(fittime, 5)}')
        print(f'Best params: {parametry}')
    print()
    
    best_models_agg.append(gs.best_estimator_) # zapisujemy model z najlepszymi parametrami
    best_params_agg.append(gs.best_params_) # oraz najlepsze wyniki
# Out:
# ---!!!--- LogisticRegression
# mean = 0.09092 || std = 0.00872 || time [s] = 0.36314
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l1', 'model__tol': 0.1}
# mean = 0.08957 || std = 0.00758 || time [s] = 1.34918
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l1', 'model__tol': 0.01}
# mean = 0.0898 || std = 0.00763 || time [s] = 2.21783
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l1', 'model__tol': 0.001}
# mean = 0.09237 || std = 0.0088 || time [s] = 0.42486
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l2', 'model__tol': 0.1}
# mean = 0.09145 || std = 0.00748 || time [s] = 0.45765
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l2', 'model__tol': 0.01}
# mean = 0.09145 || std = 0.00748 || time [s] = 0.57247
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l2', 'model__tol': 0.001}
# mean = 0.10379 || std = 0.01076 || time [s] = 0.39981
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l1', 'model__tol': 0.1}
# mean = 0.10453 || std = 0.00961 || time [s] = 1.74593
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l1', 'model__tol': 0.01}
# mean = 0.10459 || std = 0.00965 || time [s] = 2.33079
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l1', 'model__tol': 0.001}
# mean = 0.10628 || std = 0.01102 || time [s] = 0.39293
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l2', 'model__tol': 0.1}
# mean = 0.10534 || std = 0.0104 || time [s] = 0.46214
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l2', 'model__tol': 0.01}
# mean = 0.10531 || std = 0.01042 || time [s] = 0.64616
# Best params: {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l2', 'model__tol': 0.001}
# mean = 0.08653 || std = 0.00214 || time [s] = 0.37887
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l1', 'model__tol': 0.1}
# mean = 0.08397 || std = 0.00464 || time [s] = 0.44121
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l1', 'model__tol': 0.01}
# mean = 0.08283 || std = 0.00584 || time [s] = 0.52471
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l1', 'model__tol': 0.001}
# mean = 0.08819 || std = 0.008 || time [s] = 0.33847
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l2', 'model__tol': 0.1}
# mean = 0.08896 || std = 0.00899 || time [s] = 0.35585
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l2', 'model__tol': 0.01}
# mean = 0.08897 || std = 0.00905 || time [s] = 0.36419
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l2', 'model__tol': 0.001}
# mean = 0.09915 || std = 0.00782 || time [s] = 0.44205
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l1', 'model__tol': 0.1}
# mean = 0.09897 || std = 0.00854 || time [s] = 0.50452
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l1', 'model__tol': 0.01}
# mean = 0.09888 || std = 0.00857 || time [s] = 0.66342
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l1', 'model__tol': 0.001}
# mean = 0.10229 || std = 0.00878 || time [s] = 0.32218
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l2', 'model__tol': 0.1}
# mean = 0.10264 || std = 0.00866 || time [s] = 0.38246
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l2', 'model__tol': 0.01}
# mean = 0.10264 || std = 0.00866 || time [s] = 0.40317
# Best params: {'model__C': 0.01, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l2', 'model__tol': 0.001}
# mean = 0.0 || std = 0.0 || time [s] = 0.27394
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l1', 'model__tol': 0.1}
# mean = 0.0 || std = 0.0 || time [s] = 0.29736
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l1', 'model__tol': 0.01}
# mean = 0.0 || std = 0.0 || time [s] = 0.34143
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l1', 'model__tol': 0.001}
# mean = 0.07066 || std = 0.00552 || time [s] = 0.27515
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l2', 'model__tol': 0.1}
# mean = 0.07066 || std = 0.00552 || time [s] = 0.30802
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l2', 'model__tol': 0.01}
# mean = 0.07066 || std = 0.00552 || time [s] = 0.31511
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 5}, 'model__penalty': 'l2', 'model__tol': 0.001}
# mean = 0.08855 || std = 0.00483 || time [s] = 0.2704
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l1', 'model__tol': 0.1}
# mean = 0.08795 || std = 0.00542 || time [s] = 0.28805
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l1', 'model__tol': 0.01}
# mean = 0.08798 || std = 0.00539 || time [s] = 0.31667
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l1', 'model__tol': 0.001}
# mean = 0.10132 || std = 0.01003 || time [s] = 0.2964
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l2', 'model__tol': 0.1}
# mean = 0.10098 || std = 0.00901 || time [s] = 0.292
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l2', 'model__tol': 0.01}
# mean = 0.101 || std = 0.00904 || time [s] = 0.3233
# Best params: {'model__C': 0.001, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l2', 'model__tol': 0.001}
#
# ---!!!--- XGBoost
# mean = 0.05848 || std = 0.01662 || time [s] = 11.32425
# Best params: {'model__learning_rate': 0.1, 'model__max_depth': 50, 'model__n_estimators': 50}
# mean = 0.04592 || std = 0.01345 || time [s] = 16.98873
# Best params: {'model__learning_rate': 0.1, 'model__max_depth': 50, 'model__n_estimators': 75}
# mean = 0.05848 || std = 0.01662 || time [s] = 10.98594
# Best params: {'model__learning_rate': 0.1, 'model__max_depth': 75, 'model__n_estimators': 50}
# mean = 0.04592 || std = 0.01345 || time [s] = 16.61818
# Best params: {'model__learning_rate': 0.1, 'model__max_depth': 75, 'model__n_estimators': 75}
# mean = 0.05848 || std = 0.01662 || time [s] = 10.99578
# Best params: {'model__learning_rate': 0.1, 'model__max_depth': 100, 'model__n_estimators': 50}
# mean = 0.04592 || std = 0.01345 || time [s] = 16.66803
# Best params: {'model__learning_rate': 0.1, 'model__max_depth': 100, 'model__n_estimators': 75}
# mean = 0.07124 || std = 0.01191 || time [s] = 10.50742
# Best params: {'model__learning_rate': 0.01, 'model__max_depth': 50, 'model__n_estimators': 50}
# mean = 0.07427 || std = 0.00895 || time [s] = 15.81774
# Best params: {'model__learning_rate': 0.01, 'model__max_depth': 50, 'model__n_estimators': 75}
# mean = 0.07124 || std = 0.01191 || time [s] = 10.55506
# Best params: {'model__learning_rate': 0.01, 'model__max_depth': 75, 'model__n_estimators': 50}
# mean = 0.07427 || std = 0.00895 || time [s] = 15.97694
# Best params: {'model__learning_rate': 0.01, 'model__max_depth': 75, 'model__n_estimators': 75}
# mean = 0.07124 || std = 0.01191 || time [s] = 10.56661
# Best params: {'model__learning_rate': 0.01, 'model__max_depth': 100, 'model__n_estimators': 50}
# mean = 0.07427 || std = 0.00895 || time [s] = 15.82441
# Best params: {'model__learning_rate': 0.01, 'model__max_depth': 100, 'model__n_estimators': 75}
#
# ---!!!--- RandomForestClassifier
# mean = 0.0 || std = 0.0 || time [s] = 0.4435
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 400, 'model__n_estimators': 20}
# mean = 0.00194 || std = 0.00274 || time [s] = 1.07255
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 400, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 1.68473
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 400, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.30354
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 400, 'model__n_estimators': 100}
# mean = 0.0 || std = 0.0 || time [s] = 0.4356
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 500, 'model__n_estimators': 20}
# mean = 0.0 || std = 0.0 || time [s] = 1.03881
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 500, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 1.55738
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 500, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.18923
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 500, 'model__n_estimators': 100}
# mean = 0.0 || std = 0.0 || time [s] = 0.43756
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 750, 'model__n_estimators': 20}
# mean = 0.0 || std = 0.0 || time [s] = 0.99785
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 750, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 1.47855
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 750, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.18506
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 20, 'model__min_samples_leaf': 750, 'model__n_estimators': 100}
# mean = 0.00567 || std = 0.0046 || time [s] = 0.62627
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 400, 'model__n_estimators': 20}
# mean = 0.0 || std = 0.0 || time [s] = 1.42172
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 400, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 1.84638
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 400, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.65507
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 400, 'model__n_estimators': 100}
# mean = 0.0 || std = 0.0 || time [s] = 0.53875
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 500, 'model__n_estimators': 20}
# mean = 0.0 || std = 0.0 || time [s] = 1.58894
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 500, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 2.07237
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 500, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.27365
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 500, 'model__n_estimators': 100}
# mean = 0.0 || std = 0.0 || time [s] = 0.41123
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 750, 'model__n_estimators': 20}
# mean = 0.0 || std = 0.0 || time [s] = 2.72328
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 750, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 1.82799
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 750, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.39831
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 50, 'model__min_samples_leaf': 750, 'model__n_estimators': 100}
# mean = 0.00194 || std = 0.00274 || time [s] = 0.49816
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 400, 'model__n_estimators': 20}
# mean = 0.00196 || std = 0.00276 || time [s] = 1.39407
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 400, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 1.98077
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 400, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.10125
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 400, 'model__n_estimators': 100}
# mean = 0.0 || std = 0.0 || time [s] = 0.43616
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 500, 'model__n_estimators': 20}
# mean = 0.0 || std = 0.0 || time [s] = 1.22602
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 500, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 1.63677
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 500, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.33642
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 500, 'model__n_estimators': 100}
# mean = 0.0 || std = 0.0 || time [s] = 0.41636
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 750, 'model__n_estimators': 20}
# mean = 0.0 || std = 0.0 || time [s] = 1.13649
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 750, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 1.54265
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 750, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.17851
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 75, 'model__min_samples_leaf': 750, 'model__n_estimators': 100}
# mean = 0.00379 || std = 0.00536 || time [s] = 0.51697
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 400, 'model__n_estimators': 20}
# mean = 0.0 || std = 0.0 || time [s] = 1.16887
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 400, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 1.84734
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 400, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.26076
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 400, 'model__n_estimators': 100}
# mean = 0.0 || std = 0.0 || time [s] = 0.52091
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 500, 'model__n_estimators': 20}
# mean = 0.0 || std = 0.0 || time [s] = 1.14779
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 500, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 1.75954
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 500, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.36133
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 500, 'model__n_estimators': 100}
# mean = 0.0 || std = 0.0 || time [s] = 0.53536
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 750, 'model__n_estimators': 20}
# mean = 0.0 || std = 0.0 || time [s] = 1.16426
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 750, 'model__n_estimators': 50}
# mean = 0.0 || std = 0.0 || time [s] = 1.79867
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 750, 'model__n_estimators': 75}
# mean = 0.0 || std = 0.0 || time [s] = 2.09456
# Best params: {'model__class_weight': {0: 0.5, 1: 5}, 'model__max_depth': 100, 'model__min_samples_leaf': 750, 'model__n_estimators': 100}
# mean = 0.12169 || std = 0.00729 || time [s] = 0.45368
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 400, 'model__n_estimators': 20}
# mean = 0.12203 || std = 0.00185 || time [s] = 1.16416
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 400, 'model__n_estimators': 50}
# mean = 0.12216 || std = 0.00907 || time [s] = 1.7387
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 400, 'model__n_estimators': 75}
# mean = 0.11771 || std = 0.00331 || time [s] = 2.35087
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 400, 'model__n_estimators': 100}
# mean = 0.1135 || std = 0.0094 || time [s] = 0.42868
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 500, 'model__n_estimators': 20}
# mean = 0.11855 || std = 0.01053 || time [s] = 1.24813
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 500, 'model__n_estimators': 50}
# mean = 0.11575 || std = 0.00935 || time [s] = 1.89724
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 500, 'model__n_estimators': 75}
# mean = 0.11657 || std = 0.00218 || time [s] = 2.41377
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 500, 'model__n_estimators': 100}
# mean = 0.09621 || std = 0.00159 || time [s] = 0.39247
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 750, 'model__n_estimators': 20}
# mean = 0.10157 || std = 0.00231 || time [s] = 0.93876
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 750, 'model__n_estimators': 50}
# mean = 0.10814 || std = 0.00632 || time [s] = 1.38911
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 750, 'model__n_estimators': 75}
# mean = 0.10291 || std = 0.00994 || time [s] = 1.87281
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 20, 'model__min_samples_leaf': 750, 'model__n_estimators': 100}
# mean = 0.11926 || std = 0.00342 || time [s] = 0.43802
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 400, 'model__n_estimators': 20}
# mean = 0.117 || std = 0.00395 || time [s] = 1.06067
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 400, 'model__n_estimators': 50}
# mean = 0.12103 || std = 0.00447 || time [s] = 1.60805
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 400, 'model__n_estimators': 75}
# mean = 0.12399 || std = 0.004 || time [s] = 2.41451
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 400, 'model__n_estimators': 100}
# mean = 0.11737 || std = 0.00385 || time [s] = 0.41848
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 500, 'model__n_estimators': 20}
# mean = 0.11439 || std = 0.00695 || time [s] = 1.01501
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 500, 'model__n_estimators': 50}
# mean = 0.1156 || std = 0.00458 || time [s] = 1.53581
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 500, 'model__n_estimators': 75}
# mean = 0.11913 || std = 0.00366 || time [s] = 2.08678
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 500, 'model__n_estimators': 100}
# mean = 0.11093 || std = 0.00345 || time [s] = 0.38682
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 750, 'model__n_estimators': 20}
# mean = 0.10706 || std = 0.00354 || time [s] = 0.94738
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 750, 'model__n_estimators': 50}
# mean = 0.11148 || std = 0.00571 || time [s] = 1.3879
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 750, 'model__n_estimators': 75}
# mean = 0.10865 || std = 0.00651 || time [s] = 1.85533
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 50, 'model__min_samples_leaf': 750, 'model__n_estimators': 100}
# mean = 0.11455 || std = 0.00647 || time [s] = 0.43769
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 400, 'model__n_estimators': 20}
# mean = 0.12177 || std = 0.00743 || time [s] = 1.05557
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 400, 'model__n_estimators': 50}
# mean = 0.11774 || std = 0.00785 || time [s] = 1.55893
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 400, 'model__n_estimators': 75}
# mean = 0.1231 || std = 0.00577 || time [s] = 2.06347
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 400, 'model__n_estimators': 100}
# mean = 0.12168 || std = 0.00464 || time [s] = 0.41699
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 500, 'model__n_estimators': 20}
# mean = 0.11516 || std = 0.00418 || time [s] = 1.0065
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 500, 'model__n_estimators': 50}
# mean = 0.11812 || std = 0.00084 || time [s] = 1.5043
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 500, 'model__n_estimators': 75}
# mean = 0.11778 || std = 0.00189 || time [s] = 2.0069
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 500, 'model__n_estimators': 100}
# mean = 0.1092 || std = 0.00445 || time [s] = 0.3895
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 750, 'model__n_estimators': 20}
# mean = 0.10878 || std = 0.00665 || time [s] = 0.93286
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 750, 'model__n_estimators': 50}
# mean = 0.10905 || std = 0.00775 || time [s] = 1.48696
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 750, 'model__n_estimators': 75}
# mean = 0.10647 || std = 0.0044 || time [s] = 2.18678
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 75, 'model__min_samples_leaf': 750, 'model__n_estimators': 100}
# mean = 0.11498 || std = 0.00807 || time [s] = 0.46423
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 400, 'model__n_estimators': 20}
# mean = 0.12411 || std = 0.00569 || time [s] = 1.0538
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 400, 'model__n_estimators': 50}
# mean = 0.12192 || std = 0.00803 || time [s] = 1.56122
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 400, 'model__n_estimators': 75}
# mean = 0.1146 || std = 0.00181 || time [s] = 2.08944
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 400, 'model__n_estimators': 100}
# mean = 0.11619 || std = 0.00302 || time [s] = 0.42007
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 500, 'model__n_estimators': 20}
# mean = 0.11661 || std = 0.00333 || time [s] = 1.00632
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 500, 'model__n_estimators': 50}
# mean = 0.11907 || std = 0.00473 || time [s] = 1.5267
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 500, 'model__n_estimators': 75}
# mean = 0.11807 || std = 0.00185 || time [s] = 2.00358
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 500, 'model__n_estimators': 100}
# mean = 0.11745 || std = 0.01061 || time [s] = 0.38639
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 750, 'model__n_estimators': 20}
# mean = 0.11031 || std = 0.00555 || time [s] = 0.942
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 750, 'model__n_estimators': 50}
# mean = 0.11189 || std = 0.00925 || time [s] = 1.39489
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 750, 'model__n_estimators': 75}
# mean = 0.1105 || std = 0.00965 || time [s] = 1.82972
# Best params: {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 750, 'model__n_estimators': 100}

# %%
acc_agg = []
dop_agg = []
f1_agg = []
for name, best_model, best_param in zip(names_agg, best_models_agg, best_params_agg):
    acc_agg.append(accuracy_score(best_model.predict(X_test), y_test)*100)
    dop_agg.append(accuracy_score(best_model.predict(X_train), y_train)*100)
    f1_agg.append(f1_score(y_true=y_test, y_pred=best_model.predict(X_test))*100)

wyniki1 = pd.DataFrame({
    'Model': names_agg, 'Jakość predykcji': acc_agg, 'Dopasowanie': dop_agg, 
    'F1': f1_agg, 'Najlepsze parametry': best_params_agg
})
wyniki1
# Out:
#                     Model  Jakość predykcji  Dopasowanie    F1  \
# 0  LogisticRegression     92.05             92.03        10.60
# 1  XGBoost                95.95             98.59        7.84
# 2  RandomForestClassifier 95.40             95.35        13.23
#
#                                                                                                             Najlepsze parametry
# 0  {'model__C': 0.1, 'model__class_weight': {0: 0.5, 1: 10}, 'model__penalty': 'l2', 'model__tol': 0.1}
# 1  {'model__learning_rate': 0.01, 'model__max_depth': 50, 'model__n_estimators': 75}
# 2  {'model__class_weight': {0: 0.5, 1: 10}, 'model__max_depth': 100, 'model__min_samples_leaf': 400, 'model__n_estimators': 50}

# %% [markdown]
# **Podobnie jak w jupyterze 'full' najlepszy wynik dał las losowy, jednak wynik wyszedł gorszy - przy czym tutaj zastosowano zarówno wypełnienie braków w danych średnimi (tam: zerami), ponadto usunięto zmienne var, które nie były dobrze wyjaśnione w opisie danych. Można zatem uznać, że rozwiązanie z poprzedniego jupytera jest lepsze.**
